# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [1,2,3,4,5,6,7,8]
y = [20,30,40,50,60,70,80,90]

df = pd.DataFrame({"days":x,"No of people" : y})
df.head()
# Out:
#    days  No of people
# 0     1            20
# 1     2            30
# 2     3            40
# 3     4            50
# 4     5            60

# %%
#sns.lineplot(x="days", y="No of people", data=df)
#sns.catplot(x="days", y="No of people", data=df)
#sns.boxplot(x="days", y="No of people", data=df)
#sns.violinplot(x="days", y="No of people", data=df)
#sns.stripplot(x="days", y="No of people", data=df, jitter=True)
#sns.swarmplot(x="days", y="No of people", data=df)
#sns.barplot(x="days", y="No of people", data=df)
sns.scatterplot(x="days", y="No of people", data=df)
# Out:
# <Axes: xlabel='days', ylabel='No of people'>

# %%
# Load a sample dataset (Seaborn has many built-in datasets)
df = sns.load_dataset("tips")  

# Create a simple scatterplot
#sns.scatterplot(x="total_bill", y="tip", data=df)
sns.boxplot(x="total_bill", y="tip", data=df)
plt.show()
